# %% [markdown]
# ## Question no: 01

# %%
lenght =int(input("Enter the Lenght: "))
width = int(input("Enter the Width: "))
area = lenght * width
print("Area:",area)
# Out:
# Enter the Lenght:  45
# Enter the Width:  58
# Area: 2610

# %% [markdown]
# ## Question: 02

# %%
r = float(input("Enter the radius of a circle: "))
pi = 3.14159
circumference = 2 * r * pi
print("Circumference of the circle is: ",circumference)
# Out:
# Enter the radius of a circle:  20
# Circumference of the circle is:  125.6636

# %% [markdown]
# ## Question: 03

# %%
##### p = float(input("Enter the Principal: "))
r = float(input("Enter the Rate: "))
t = float(input("Enter the Time: "))
si = p * r * t
print("Simple Interest",si)
# Out:
# Enter the Rate:  40000
# Enter the Time:  4
# Simple Interest 320000000.0

# %% [markdown]
# ## Question: 04

# %%
distance = float(input("Enter the Distance: "))
time = float(input("Enter the Time: "))
speed = distance / time
print("Speed", speed )
# Out:
# Enter the Distance:  52
# Enter the Time:  2
# Speed 26.0

# %% [markdown]
# ## Question: 05

# %%
weight = float(input("Enter the weight  (kg) : "))
height = float(input("Enter the height  (m) : "))
bmi = weight / (height**2)
print("BMI is : ", bmi)
# Out:
# Enter the weight  (kg) :  50
# Enter the height  (m) :  5.6
# BMI is :  1.5943877551020411

# %% [markdown]
# ## Question: 06

# %%
mass = float(input("Enter mass (kg)"))
acceleration = float(input("Enter Acceleration"))
force = mass * acceleration
print("Force",force)
# Out:
# Enter mass (kg) 50
# Enter Acceleration 70
# Force 3500.0

# %% [markdown]
# ## Question: 07

# %%
p = float(input("Enter the Principal amount (P): "))
r = float(input("Enter the annual interest (r): "))
n = float(input("Enter compounded times (n):"))
t = float(input("Enter  years (t): "))
a = p *(1+(r/n)** (n*t))
print("Compound Interest Amount:",a)
# Out:
# Enter the Principal amount (P):  12
# Enter the annual interest (r):  12
# Enter compounded times (n): 5
# Enter  years (t):  11
# Compound Interest Amount: 9.79037980880305e+21

# %% [markdown]
# ## Question: 08

# %%
a = float(input("Enter side of a: "))
b = float(input("Enter side of b: "))
c = float(input("Enter side of c: "))
p = a + b + c
print("Perimeter: ", p)
# Out:
# Enter side of a:  10
# Enter side of b:  44
# Enter side of c:  7
# Perimeter:  61.0

# %% [markdown]
# ## Question: 09

# %% [markdown]
# r = float(input("Enter the radius: "))
# volume = (4/3)* 3.14159*(r**3)
# print("Volumne of Sphere: ",volume)

# %% [markdown]
# ## Question: 10

# %%
m = float(input("Enter mass (kg):"))
v = float(input("Enter velocity (m/s):"))
ke = (1/2)*m*(v**2)
print("Kinetic Energy:",ke)
# Out:
# Enter mass (kg): 50.4
# Enter velocity (m/s): 11
# Kinetic Energy: 3049.2

# %% [markdown]
# ## Question: 11

# %%
a = float(input("Enter the a:"))
b = float(input("Enter the b:"))
c= float(input("Enter the c:"))

d = (b**2) - (4*a*c)
x1 = (-b + (d ** 0.5)) / (2*a)
x2 = (-b - (d ** 0.5 )) / (2*a) 
print ("Roots:", x1, "and", x2)
# Out:
# Enter the a: 50
# Enter the b: 4
# Enter the c: 55
# Roots: (-0.03999999999999994+1.0480458005259121j) and (-0.04000000000000006-1.0480458005259121j)

# %% [markdown]
# ## Question: 12

# %%
c = float(input("Enter Temperature in Celsius: "))
f = ( (9/5) *c ) + 32
print("Temperature in Fahrenheit:",f)
# Out:
# Enter Temperature in Celsius:  21.5
# Temperature in Fahrenheit: 70.7

# %% [markdown]
# ## Question: 13

# %%
m1 = float(input("Enter the Mass 1: "))
m2 = float(input("Enter the Mass 2 :"))
r = float(input("Enter the distance (r): "))
g = 6.674e-11
f = g * ((m1 * m2) / (r**2) )
print("Gravitional Force :", f)
# Out:
# Enter the Mass 1:  20
# Enter the Mass 2 : 50
# Enter the distance (r):  20.5
# Gravitional Force : 1.5881023200475905e-10

# %% [markdown]
# ## Question: 14

# %%
r = float(input("Enter  radius"))
h = float(input("Enter height"))
volume = 3.14159 * (r**2) * h
print("Volume of Cylinder: ", volume)
# Out:
# Enter  radius 2.14
# Enter height 52.1
# Volume of Cylinder:  749.5744518844

# %% [markdown]
# ## Question: 15

# %%
F = float(input("Enter Force : "))
A = float(input("Enter Area: "))
p = F / A
print("Pressure :" , p)
# Out:
# Enter Force :  20
# Enter Area:  25.5
# Pressure : 0.7843137254901961

# %% [markdown]
# ## Question : 16

# %%
V = float(input("Enter Voltage: "))
I = float(input("Enter Current: "))
p = V / I
print("Power:", p)
# Out:
# Enter Voltage:  25.5
# Enter Current:  500
# Power: 0.051

# %% [markdown]
# ## Question: 17

# %%
r = float(input("Enter radius: "))
p = 2 * 3.14159 * r
print("Perimeter of Circle:", p)
# Out:
# Enter radius:  12.4
# Perimeter of Circle: 77.911432

# %% [markdown]
# ## Question: 18

# %%
PV = float(input("Enter Present Value (PV): "))
r = float(input("Enter Rate (r): "))
t = float(input("Enter Time in year (t):"))
FV = PV * ((1 + r)**t)
print("Future Value:", FV )
# Out:
# Enter Present Value (PV):  25
# Enter Rate (r):  5
# Enter Time in year (t): 1.5
# Future Value: 367.42346141747674

# %% [markdown]
# ## Question: 19

# %%
f = float(input("Enter Force: "))
d = float(input("Enter Distance: "))
cos_theta = float(input("Enter the value of cos(theta):"))
w = f * d * cos_theta
print("Work Done (W):", w)
# Out:
# Enter Force:  20
# Enter Distance:  54
# Enter the value of cos(theta): 10
# Work Done (W): 10800.0

# %% [markdown]
# ## Question: 20

# %%
m = float(input("Enter Mass: "))
c = float(input("Enter Specific Heat Capacity: "))
T = float(input("Enter Temperature change (T): "))
Q = m * c * T
print("Heat Transferred: ", Q)
# Out:
# Enter Mass:  50.1
# Enter Specific Heat Capacity:  54
# Enter Temperature change (T):  5
# Heat Transferred:  13527.0
